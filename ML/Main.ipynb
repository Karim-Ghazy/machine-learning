# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df['score_sum'] = [sum(x) for x in zip(df['math score'], df['reading score'], df['writing score'])]

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  score_sum
# 0                    none          72             72             74        218
# ...

# %%
df2 = df.drop(['gender', 'race/ethnicity', 'lunch', 'test preparation course', 'math score' ,'reading score', 'writing score'], axis=1, inplace = False)

# %%
le = LabelEncoder()
encodeddegree = le.fit_transform(df['parental level of education'])

# %%
df2 = df2.drop(['parental level of education'], axis=1, inplace = False)

# %%
df2['parent degree'] = encodeddegree

# %%
df2.head(10)
# Out:
#    score_sum  parent degree
# 0        218              1
# 1        247              4
# 2        278              3
# 3        148              0
# 4        229              4
# 5        232              0
# 6        275              4
# 7        122              4
# 8        195              2
# 9        148              2

# %%
dataarray = df2.to_numpy()

# %%
dataarray
# Out:
# array([[218,   1],
#        [247,   4],
#        [278,   3],
#        ...,
#        [195,   2],
#        [223,   4],
#        [249,   4]], dtype=int64)

# %%
#logistic regression
